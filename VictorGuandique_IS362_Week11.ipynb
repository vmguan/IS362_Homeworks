# %% [markdown]
# # IS362 Assignment Web APIs

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ## Get the data from API as Json and save as response

# %%
response = requests.get('https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key=gyVbKgYRFNyDBTUHbzvDsDQV7KSoYaMp').json()
response
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'uri': 'nyt://article/d44ee463-9e46-58d5-8b12-7b4d8d257d8b',
#    'url': 'https://www.nytimes.com/2021/11/05/us/politics/house-infrastructure-reconciliation.html',
#    'id': 100000008060495,
#    'asset_id': 100000008060495,
#    'source': 'New York Times',
#    'published_date': '2021-11-05',
#    'updated': '2021-11-07 14:15:55',
#    'section': 'U.S.',
#    'subsection': 'Politics',
#    'nytdsection': 'u.s.',
#    'adx_keywords': 'American Jobs Plan (2021);Infrastructure (Public Works);Law and Legislation;United States Politics and Government;Biden, Joseph R Jr;Democratic Party;House of Representatives',
#    'column': None,
#    'byline': 'By Jonathan Weisman, Emily Cochrane and Catie Edmondson',
#    'type': 'Article',
#    'title': 'House Passes $1 Trillion Infrastructure Bill, Putting Social Policy Bill on Hold',
# ...

# %% [markdown]
# ## Print the keys in response ( nested dictionary)

# %%
for item in response:
    print (item)
# Out:
# status
# copyright
# num_results
# results

# %% [markdown]
# ## Get the information from the key results and save it into variable name data

# %%
data = response['results']
data
# Out:
# [{'uri': 'nyt://article/d44ee463-9e46-58d5-8b12-7b4d8d257d8b',
#   'url': 'https://www.nytimes.com/2021/11/05/us/politics/house-infrastructure-reconciliation.html',
#   'id': 100000008060495,
#   'asset_id': 100000008060495,
#   'source': 'New York Times',
#   'published_date': '2021-11-05',
#   'updated': '2021-11-07 14:15:55',
#   'section': 'U.S.',
#   'subsection': 'Politics',
#   'nytdsection': 'u.s.',
#   'adx_keywords': 'American Jobs Plan (2021);Infrastructure (Public Works);Law and Legislation;United States Politics and Government;Biden, Joseph R Jr;Democratic Party;House of Representatives',
#   'column': None,
#   'byline': 'By Jonathan Weisman, Emily Cochrane and Catie Edmondson',
#   'type': 'Article',
#   'title': 'House Passes $1 Trillion Infrastructure Bill, Putting Social Policy Bill on Hold',
# ...

# %% [markdown]
# ## iterate to get the items in data

# %%
for item in data:
    print(item)
# Out:
# {'uri': 'nyt://article/d44ee463-9e46-58d5-8b12-7b4d8d257d8b', 'url': 'https://www.nytimes.com/2021/11/05/us/politics/house-infrastructure-reconciliation.html', 'id': 100000008060495, 'asset_id': 100000008060495, 'source': 'New York Times', 'published_date': '2021-11-05', 'updated': '2021-11-07 14:15:55', 'section': 'U.S.', 'subsection': 'Politics', 'nytdsection': 'u.s.', 'adx_keywords': 'American Jobs Plan (2021);Infrastructure (Public Works);Law and Legislation;United States Politics and Government;Biden, Joseph R Jr;Democratic Party;House of Representatives', 'column': None, 'byline': 'By Jonathan Weisman, Emily Cochrane and Catie Edmondson', 'type': 'Article', 'title': 'House Passes $1 Trillion Infrastructure Bill, Putting Social Policy Bill on Hold', 'abstract': 'Progressives who had threatened to sink the measure agreed to support it after extracting a promise from moderates that they would ultimately back the social safety net and climate bill.', 'des_facet': ['American Jobs Pl
# ...

# %% [markdown]
# ## iterate in items to print the keys

# %%
for x in item:
    print(x)
# Out:
# uri
# url
# id
# asset_id
# source
# published_date
# updated
# section
# subsection
# nytdsection
# adx_keywords
# column
# byline
# type
# title
# abstract
# des_facet
# org_facet
# per_facet
# geo_facet
# media
# eta_id

# %% [markdown]
# ## Convert the data dictionary into a pandas DataFrame and print some of the fields

# %%
df = pd.DataFrame(data,columns = ['id','source','published_date','section','byline','title','abstract'])
df
# Out:
#                  id          source published_date   section  \
# 0   100000008060495  New York Times     2021-11-05      U.S.
# 1   100000008064540  New York Times     2021-11-06      U.S.
# 2   100000008031185  New York Times     2021-11-05  New York
# 3   100000008063111  New York Times     2021-11-06   Science
# 4   100000008064530  New York Times     2021-11-06      U.S.
# 5   100000008064666  New York Times     2021-11-06     World
# 6   100000008064142  New York Times     2021-11-05      Arts
# 7   100000008059143  New York Times     2021-11-05      U.S.
# 8   100000008062338  New York Times     2021-11-06   Opinion
# 9   100000008046205  New York Times     2021-11-04    Sports
# 10  100000008061450  New York Times     2021-11-06      U.S.
# 11  100000008062573  New York Times     2021-11-05      U.S.
# 12  100000008032480  New York Times     2021-11-01   Opinion
# 13  100000008064668  New York Times     2021-11-06    Sports
# ...
